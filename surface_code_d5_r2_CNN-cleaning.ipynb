# %%
from matplotlib import pyplot as plt
import pymatching
import numpy as np
from copy import deepcopy
from circuit_generators import *
from sampling_functions import *
from bitpack import pack_bits, unpack_bits
from circuit_partition import *
from utilities_tf import *
from CNNModel import *
import time 
from keras.optimizers import Adam
import os
import json 
import pickle

t0 = time.time()

# Number of worker nodes
n_worker_nodes = 8

# Surface code specifications
d = 5
r = 2
kernel_size = 3

# Error probabilities
p = 0.01
before_round_data_depolarization = p
after_reset_flip_probability = p
after_clifford_depolarization = p
before_measure_flip_probability = p

use_rotated_z = True
observable_type = "ZL" if use_rotated_z else "XL"

# Bit types
binary_t = np.int8 # Could use even less if numpy allowed

# Measurement index type
idx_t = np.int8
n_all_measurements = r*(d**2-1) + d**2
if n_all_measurements > np.iinfo(idx_t).max:
  idx_t = np.int16
if n_all_measurements > np.iinfo(idx_t).max:
  idx_t = np.int32
if n_all_measurements > np.iinfo(idx_t).max:
  idx_t = np.int64
if n_all_measurements > np.iinfo(idx_t).max:
  idx_t = np.int128
if n_all_measurements > np.iinfo(idx_t).max:
  idx_t = np.int256
if n_all_measurements > np.iinfo(idx_t).max:
  raise RuntimeError("idx_t is too small.")

# Call signature for circuit_partition::group_det_bits_kxk
call_group_det_bits_kxk = lambda det_bits_dxd, data_bits_dxd=None, d=d, r=r, k=kernel_size, use_rotated_z=use_rotated_z, binary_t=binary_t, idx_t=idx_t: group_det_bits_kxk(det_bits_dxd, d, r, k, use_rotated_z, data_bits_dxd, binary_t, idx_t)
# Out:
# 2024-06-19 15:00:06.419030: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def split_measurements(measurements, d):
  n_measurements = idx_t(measurements.shape[1])
  # Measurements on data qubits come last
  exclude_indices = np.array([-x-1 for x in range(d**2)], dtype=idx_t)
  exclude_indices = exclude_indices + n_measurements
  # Out of all measurements on data qubits, the logical qubit measurements are those on the boundary of the lattice.
  # All other equivalent X_L/Z_L operators can be found through the combination of ancilla measurements and the chosen data qubits giving us the logical qubit.
  exclude_indices_obsL = np.array([-x-1 for x in range(d*(d-1), d**2)], dtype=idx_t)
  exclude_indices_obsL = exclude_indices_obsL + n_measurements
  # From obs_bits, we want to exclude all measurements except those listed in exclude_indices_obsL
  exclude_indices_obs = np.arange(0, n_measurements, 1, dtype=idx_t)
  exclude_indices_obs = np.delete(exclude_indices_obs, exclude_indices_obsL)

  det_bits = measurements
  det_bits = np.delete(det_bits, exclude_indices, axis=1)
  obs_bits = measurements
  obs_bits = np.delete(obs_bits, exclude_indices_obs, axis=1)

  data_bits = measurements[:, exclude_indices]

  # Reverse the order of data_bits because exclude_indices starts from the last data qubit measurement, not the first
  data_bits = np.flip(data_bits, axis=1)

  return det_bits, obs_bits, data_bits

# %%
def get_stim_output(n_total, split):
  # this is using globals defined in the first cell!
  n_test = int(n_total*split)
  n_train = int(n_total*(1-split))
  n_samples = n_test + n_train
  decoders = ['pymatching']
  test_circuit = get_builtin_circuit(
    "surface_code:rotated_memory_"+('z' if use_rotated_z else 'x'),
    distance=d,
    rounds=r,
    before_round_data_depolarization = before_round_data_depolarization,
    after_reset_flip_probability = after_reset_flip_probability,
    after_clifford_depolarization = after_clifford_depolarization,
    before_measure_flip_probability = before_measure_flip_probability
  )

  kernel_circuit_extra_depol1 = [
    [
      f"DEPOLARIZE1({after_clifford_depolarization}) 13 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 5 13 17 19 25",
      f"#DEPOLARIZE1({after_clifford_depolarization})",
      f"DEPOLARIZE1({after_clifford_depolarization}) 12 15 19",
    ], # parity = (1, 1)
    [
      f"DEPOLARIZE1({after_clifford_depolarization}) 8 13 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 5 13 17 19 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 1 14 15",
      f"DEPOLARIZE1({after_clifford_depolarization}) 12 14 15 19",
    ], # parity = (0, 1)
    [
      f"DEPOLARIZE1({after_clifford_depolarization}) 8 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 17 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 1 14 15",
      f"DEPOLARIZE1({after_clifford_depolarization}) 14 15",
    ], # parity = (-1, 1)
    [
      f"DEPOLARIZE1({after_clifford_depolarization}) 5 13 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 5 13 17 19 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 2 3",
      f"DEPOLARIZE1({after_clifford_depolarization}) 2 12 15 19",
    ], # parity = (1, 0)
    [
      f"DEPOLARIZE1({after_clifford_depolarization}) 1 5 8 13 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 5 13 17 19 25",
      f"DEPOLARIZE1({after_clifford_depolarization}) 1 2 3 14 15",
      f"DEPOLARIZE1({after_clifford_depolarization}) 2 12 14 15 19",
    ] # parity = (0, 0)
  ]
  kernel_circuits = []
  for replace_args in kernel_circuit_extra_depol1:
    kernel_circuit_template = \
    f"""
  QUBIT_COORDS(1, 1) 1
  QUBIT_COORDS(2, 0) 2
  QUBIT_COORDS(3, 1) 3
  QUBIT_COORDS(5, 1) 5
  QUBIT_COORDS(1, 3) 8
  QUBIT_COORDS(2, 2) 9
  QUBIT_COORDS(3, 3) 10
  QUBIT_COORDS(4, 2) 11
  QUBIT_COORDS(5, 3) 12
  QUBIT_COORDS(6, 2) 13
  QUBIT_COORDS(0, 4) 14
  QUBIT_COORDS(1, 5) 15
  QUBIT_COORDS(2, 4) 16
  QUBIT_COORDS(3, 5) 17
  QUBIT_COORDS(4, 4) 18
  QUBIT_COORDS(5, 5) 19
  QUBIT_COORDS(4, 6) 25
  R 1 3 5 8 10 12 15 17 19
  X_ERROR({after_reset_flip_probability}) 1 3 5 8 10 12 15 17 19
  R 2 9 11 13 14 16 18 25
  X_ERROR({after_reset_flip_probability}) 2 9 11 13 14 16 18 25
  TICK
  DEPOLARIZE1({before_round_data_depolarization}) 1 3 5 8 10 12 15 17 19
  H 2 11 16 25
  DEPOLARIZE1({after_clifford_depolarization}) 2 11 16 25
  TICK
  CX 2 3 16 17 11 12 15 14 10 9 19 18
  DEPOLARIZE2({after_clifford_depolarization}) 2 3 16 17 11 12 15 14 10 9 19 18
  {replace_args[0]}
  TICK
  CX 2 1 16 15 11 10 8 14 3 9 12 18
  DEPOLARIZE2({after_clifford_depolarization}) 2 1 16 15 11 10 8 14 3 9 12 18
  {replace_args[1]}
  TICK
  CX 16 10 11 5 25 19 8 9 17 18 12 13
  DEPOLARIZE2({after_clifford_depolarization}) 16 10 11 5 25 19 8 9 17 18 12 13
  {replace_args[2]}
  TICK
  CX 16 8 11 3 25 17 1 9 10 18 5 13
  DEPOLARIZE2({after_clifford_depolarization}) 16 8 11 3 25 17 1 9 10 18 5 13
  {replace_args[3]}
  TICK
  H 2 11 16 25
  DEPOLARIZE1({after_clifford_depolarization}) 2 11 16 25
  TICK
  X_ERROR({before_measure_flip_probability}) 2 9 11 13 14 16 18 25
  MR 2 9 11 13 14 16 18 25
  X_ERROR({after_reset_flip_probability}) 2 9 11 13 14 16 18 25
  DETECTOR(0, 4, 0) rec[-4]
  DETECTOR(2, 2, 0) rec[-7]
  DETECTOR(4, 4, 0) rec[-2]
  DETECTOR(6, 2, 0) rec[-5]
  REPEAT {r-1} {{
    TICK
    DEPOLARIZE1({before_round_data_depolarization}) 1 3 5 8 10 12 15 17 19
    H 2 11 16 25
    DEPOLARIZE1({after_clifford_depolarization}) 2 11 16 25
    TICK
    CX 2 3 16 17 11 12 15 14 10 9 19 18
    DEPOLARIZE2({after_clifford_depolarization}) 2 3 16 17 11 12 15 14 10 9 19 18
    {replace_args[0]}
    TICK
    CX 2 1 16 15 11 10 8 14 3 9 12 18
    DEPOLARIZE2({after_clifford_depolarization}) 2 1 16 15 11 10 8 14 3 9 12 18
    {replace_args[1]}
    TICK
    CX 16 10 11 5 25 19 8 9 17 18 12 13
    DEPOLARIZE2({after_clifford_depolarization}) 16 10 11 5 25 19 8 9 17 18 12 13
    {replace_args[2]}
    TICK
    CX 16 8 11 3 25 17 1 9 10 18 5 13
    DEPOLARIZE2({after_clifford_depolarization}) 16 8 11 3 25 17 1 9 10 18 5 13
    {replace_args[3]}
    TICK
    H 2 11 16 25
    DEPOLARIZE1({after_clifford_depolarization}) 2 11 16 25
    TICK
    X_ERROR({before_measure_flip_probability}) 2 9 11 13 14 16 18 25
    MR 2 9 11 13 14 16 18 25
    X_ERROR({after_reset_flip_probability}) 2 9 11 13 14 16 18 25
    SHIFT_COORDS(0, 0, 1)
    DETECTOR(2, 0, 0) rec[-8] rec[-16]
    DETECTOR(2, 2, 0) rec[-7] rec[-15]
    DETECTOR(4, 2, 0) rec[-6] rec[-14]
    DETECTOR(6, 2, 0) rec[-5] rec[-13]
    DETECTOR(0, 4, 0) rec[-4] rec[-12]
    DETECTOR(2, 4, 0) rec[-3] rec[-11]
    DETECTOR(4, 4, 0) rec[-2] rec[-10]
    DETECTOR(4, 6, 0) rec[-1] rec[-9]
  }}
  X_ERROR({before_measure_flip_probability}) 1 3 5 8 10 12 15 17 19
  M 1 3 5 8 10 12 15 17 19
  DETECTOR(0, 4, 1) rec[-3] rec[-6] rec[-13]
  DETECTOR(2, 2, 1) rec[-5] rec[-6] rec[-8] rec[-9] rec[-16]
  DETECTOR(4, 4, 1) rec[-1] rec[-2] rec[-4] rec[-5] rec[-11]
  DETECTOR(6, 2, 1) rec[-4] rec[-7] rec[-14]
  OBSERVABLE_INCLUDE(0) rec[-7] rec[-8] rec[-9]
    """
    kernel_circuits.append(stim.Circuit(kernel_circuit_template))


  # Sampling for the dxd circuit
  m_sampler = test_circuit.compile_sampler(seed=12345)
  converter = test_circuit.compile_m2d_converter()
  detector_error_model = test_circuit.detector_error_model(decompose_errors=True)

  measurements = m_sampler.sample(n_samples, bit_packed=False)
  det_evts, flips = converter.convert(measurements=measurements, separate_observables=True, bit_packed=False)
  measurements = measurements.astype(binary_t)
  det_evts = det_evts.astype(binary_t)
  flips = flips.astype(binary_t)

  avg_flips = np.sum(flips.reshape(-1,), dtype=np.float32)/flips.shape[0]
  print(f"Average flip rate for the full circuit: {avg_flips}")

  # next cell
  n_measurements = idx_t(measurements.shape[1])
  det_bits, obs_bits, data_bits = split_measurements(measurements, d)

  # next cell
  det_bits_kxk_all, data_bits_kxk_all, obs_bits_kxk_all, kernel_result_translation_map = call_group_det_bits_kxk(det_bits, data_bits_dxd=data_bits)
  kernel_types = get_unique_kernel_types(kernel_size, d)
  n_kernels = det_bits_kxk_all.shape[0]

  # next cell
  kernel_result_translation_map_f = kernel_result_translation_map[:,:,1:]
  kernel_result_translation_map_b = kernel_result_translation_map[:,:,0:-1]
  kernel_result_translation_det_evts = (kernel_result_translation_map_f!=kernel_result_translation_map_b).astype(binary_t)
  kernel_result_translation_map = np.concatenate((kernel_result_translation_map, kernel_result_translation_det_evts), axis=2)

  # next cell
  det_evts_kxk_all = []
  flips_kxk_all = []
  converters_kernel = []
  for kernel_circuit in kernel_circuits:
    converters_kernel.append(kernel_circuit.compile_m2d_converter())
  for k in range(n_kernels):
    measurements_kxk = np.concatenate((det_bits_kxk_all[k], data_bits_kxk_all[k]), axis=1).astype(np.bool_)
    ik = 0
    for i, kernel_type in enumerate(kernel_types):
      if k in kernel_type[1]:
        ik = i
        break
    det_evts_kxk, flips_kxk = converters_kernel[ik].convert(measurements=measurements_kxk, separate_observables=True, bit_packed=False)
    det_evts_kxk_all.append(det_evts_kxk)
    flips_kxk_all.append(flips_kxk)
  det_evts_kxk_all = np.array(det_evts_kxk_all, dtype=binary_t)
  flips_kxk_all = np.array(flips_kxk_all, dtype=binary_t)
  del converters_kernel

  # next cell
  class_bits = flips
  features_det_bits = np.swapaxes(det_bits_kxk_all, 0, 1)
  features_det_evts = np.swapaxes(det_evts_kxk_all, 0, 1)
  features_translation_map = np.swapaxes(kernel_result_translation_map, 0, 1) # Dimensions go as [sample][kernel][cycle bits + detections (n_cycles-1)]
  features_translation_map = np.reshape(features_translation_map, (features_translation_map.shape[0], -1))
  features_final_det_evts = det_evts[:, -((d**2-1)//2):]

  return {"CNN": [[features_det_bits,
                   features_det_evts,
                   features_translation_map,
                   features_final_det_evts],
                  class_bits], 
          "pymatch": [detector_error_model, det_evts, flips]}

# %%
def get_pymatching_result(stim_output, idxs_test):
    detector_error_model, det_evts, flips = stim_output["pymatch"]
    pymatcher = pymatching.Matching.from_detector_error_model(detector_error_model)
    flips_pred_pym = pymatcher.decode_batch(det_evts, bit_packed_predictions=False, bit_packed_shots=False).astype(binary_t).reshape(-1,1)
    flips_pred_pym = pymatcher.decode_batch(det_evts[idxs_test,:], bit_packed_predictions=False, bit_packed_shots=False).astype(binary_t).reshape(-1,1)
    pymatch_error_rate_test = np.sum(
        (flips_pred_pym!=flips[idxs_test,:]))/flips_pred_pym.shape[0]
    return pymatch_error_rate_test

# %%
def learning_rate_scheduler(epoch, lr):
  if epoch < 10:
    return lr
  elif epoch < 20:
    return lr * 0.9
  elif epoch < 30:
    return lr * 0.8
  else:
    return lr * 0.65

# %%
name = "sc-CNN-training-lr0.0005"
n_totals = np.array([10**5, 10**6, 10**7], dtype=int)
frac_test = 0.2
batch_size = 10**3  
n_epochs = 60
n_nodes = 150
lr = 0.0005

# %%
# save params 
params = {
  "d": d,
  "r": r,
  "kernel_size": kernel_size,
  "p": p,
  "before_round_data_depolarization": before_round_data_depolarization,
  "after_reset_flip_probability": after_reset_flip_probability,
  "after_clifford_depolarization": after_clifford_depolarization,
  "before_measure_flip_probability": before_measure_flip_probability,
  "use_rotated_z": use_rotated_z,
  "observable_type": observable_type,
  "name": name,
  "n_totals": n_totals.tolist(),
  "frac_test": frac_test,
  "batch_size": batch_size,
  "n_epochs": n_epochs,
  "n_nodes": n_nodes,
  "lr": lr,
  "history_paths": [f"{name}/model_{n_total:0.3e}.json" for n_total in n_totals]
}
os.makedirs(name, exist_ok=True)
param_filename = os.path.join(name, "setup.json")
with open(param_filename, "w") as f: json.dump(params, f)

# run stim
max_total = np.max(n_totals)
stim_output = get_stim_output(max_total, frac_test)
[[features_det_bits,
  features_det_evts,
  features_translation_map,
  features_final_det_evts], class_bits] = stim_output["CNN"]

# PyMatching error rate
pymatch_error_rate = get_pymatching_result(
  stim_output, np.arange(max_total, dtype=np.int32))
print(f"PyMatching error rate for full data set: "
      f"{100*pymatch_error_rate:0.4f}%")

histories = []
best_rounds = []
best_accuracies = []
for i_n, n_total in enumerate(n_totals):
  # train-test split
  # Make sure the data type is np.int32 below, not idx_t!
  idxs_test, idxs_train = split_data(
      np.arange(n_total, dtype=np.int32), 
      test_size=frac_test, 
      seed=12345, shuffle=False)
  
  # package stim output
  data = {}
  for label, index in zip(["test", "train"], 
                          [idxs_test, idxs_train]):
      data[label] = [features_det_bits[index], 
                      features_det_evts[index],
                      features_translation_map[index], 
                      features_final_det_evts[index] ]
  
  # train the model
  print(f"\nTraining CNN model for {n_total:0.1e} samples")
  model_dxd = FullCNNModel(
    observable_type, d, kernel_size, r,
    [n_nodes for _ in range(2)], npol=2,
    do_all_data_qubits=False, extended_kernel_output=True, 
    include_det_evts=True, include_last_kernel_dets=False, 
    include_last_dets=True, has_nonuniform_response=False, 
    use_translated_kernels=False
  )
  model_dxd.compile(optimizer=Adam(learning_rate=lr), 
                    loss='binary_crossentropy', metrics=['accuracy'])
  history = model_dxd.fit(
    x=data["train"],
    y=class_bits[idxs_train,:],
    batch_size=batch_size,
    epochs=n_epochs, 
    validation_data=(data["test"], class_bits[idxs_test,:]),
    callbacks=[
      # tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,
      #                                 restore_best_weights=True),
      # tf.keras.callbacks.LearningRateScheduler(learning_rate_scheduler)
    ]
  )
  with open(params["history_paths"][i_n], "w") as f: 
     json.dump(history.history, f)
  histories.append(history)
  
  # evaluate the model
  print(f"\nFor {n_total:0.1e} samples:")
  best_rounds.append(np.argmax(history.history['val_accuracy']))
  best_accuracies.append(history.history['val_accuracy'][best_rounds[-1]])
  print(f"Best CNN test error rate: {100*(1-best_accuracies[-1]):.4f}% "
        f"in epoch {best_rounds[-1] + 1}/{n_epochs}")
  print()
# Out:
# Average flip rate for the full circuit: 0.2298373
# PyMatching error rate for full data set: 3.1560%
#
# Training CNN model for 1.0e+05 samples
# Number of unique contributions: 13
# Total number of fractions: 28
# Total number of phases: 62
# Epoch 1/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 185ms/step - accuracy: 0.6686 - loss: 0.6243 - val_accuracy: 0.7687 - val_loss: 0.5264
# Epoch 2/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7728 - loss: 0.5150 - val_accuracy: 0.7687 - val_loss: 0.4927
# Epoch 3/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.7727 - loss: 0.4791 - val_accuracy: 0.7780 - val_loss: 0.4622
# Epoch 4/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.7840 - loss: 0.4496 - val_accuracy: 0.7821 - val_loss: 0.4426
# Epoch 5/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7846 - loss: 0.4352 - val_accuracy: 0.7788 - val_loss: 0.4278
# Epoch 6/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.7819 - loss: 0.4219 - val_accuracy: 0.7780 - val_loss: 0.4161
# Epoch 7/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.7854 - loss: 0.4069 - val_accuracy: 0.7830 - val_loss: 0.4063
# Epoch 8/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7920 - loss: 0.3926 - val_accuracy: 0.7904 - val_loss: 0.3955
# Epoch 9/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8001 - loss: 0.3845 - val_accuracy: 0.8045 - val_loss: 0.3830
# Epoch 10/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8155 - loss: 0.3668 - val_accuracy: 0.8150 - val_loss: 0.3699
# Epoch 11/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8267 - loss: 0.3588 - val_accuracy: 0.8274 - val_loss: 0.3567
# Epoch 12/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8390 - loss: 0.3414 - val_accuracy: 0.8369 - val_loss: 0.3446
# Epoch 13/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8478 - loss: 0.3326 - val_accuracy: 0.8444 - val_loss: 0.3351
# Epoch 14/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8539 - loss: 0.3179 - val_accuracy: 0.8485 - val_loss: 0.3270
# Epoch 15/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8617 - loss: 0.3053 - val_accuracy: 0.8508 - val_loss: 0.3201
# Epoch 16/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8668 - loss: 0.2964 - val_accuracy: 0.8597 - val_loss: 0.3136
# Epoch 17/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8699 - loss: 0.2949 - val_accuracy: 0.8593 - val_loss: 0.3046
# Epoch 18/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8729 - loss: 0.2846 - val_accuracy: 0.8640 - val_loss: 0.2976
# Epoch 19/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8793 - loss: 0.2720 - val_accuracy: 0.8701 - val_loss: 0.2919
# Epoch 20/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8863 - loss: 0.2639 - val_accuracy: 0.8717 - val_loss: 0.2853
# Epoch 21/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8871 - loss: 0.2613 - val_accuracy: 0.8755 - val_loss: 0.2810
# Epoch 22/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8946 - loss: 0.2489 - val_accuracy: 0.8774 - val_loss: 0.2758
# Epoch 23/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8982 - loss: 0.2427 - val_accuracy: 0.8773 - val_loss: 0.2750
# Epoch 24/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9007 - loss: 0.2368 - val_accuracy: 0.8828 - val_loss: 0.2692
# Epoch 25/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9031 - loss: 0.2293 - val_accuracy: 0.8843 - val_loss: 0.2661
# Epoch 26/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9062 - loss: 0.2280 - val_accuracy: 0.8854 - val_loss: 0.2624
# Epoch 27/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9088 - loss: 0.2209 - val_accuracy: 0.8879 - val_loss: 0.2574
# Epoch 28/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9110 - loss: 0.2159 - val_accuracy: 0.8890 - val_loss: 0.2563
# Epoch 29/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9081 - loss: 0.2183 - val_accuracy: 0.8900 - val_loss: 0.2539
# Epoch 30/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9146 - loss: 0.2111 - val_accuracy: 0.8928 - val_loss: 0.2493
# Epoch 31/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9163 - loss: 0.2020 - val_accuracy: 0.8930 - val_loss: 0.2490
# Epoch 32/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9179 - loss: 0.2024 - val_accuracy: 0.8941 - val_loss: 0.2468
# Epoch 33/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9195 - loss: 0.1972 - val_accuracy: 0.8971 - val_loss: 0.2433
# Epoch 34/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9254 - loss: 0.1885 - val_accuracy: 0.8967 - val_loss: 0.2411
# Epoch 35/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9239 - loss: 0.1869 - val_accuracy: 0.8968 - val_loss: 0.2407
# Epoch 36/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9268 - loss: 0.1864 - val_accuracy: 0.8988 - val_loss: 0.2390
# Epoch 37/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9301 - loss: 0.1769 - val_accuracy: 0.8988 - val_loss: 0.2391
# Epoch 38/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9290 - loss: 0.1809 - val_accuracy: 0.8976 - val_loss: 0.2409
# Epoch 39/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9297 - loss: 0.1782 - val_accuracy: 0.9012 - val_loss: 0.2327
# Epoch 40/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9306 - loss: 0.1722 - val_accuracy: 0.9010 - val_loss: 0.2363
# Epoch 41/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9337 - loss: 0.1708 - val_accuracy: 0.9016 - val_loss: 0.2339
# Epoch 42/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9328 - loss: 0.1693 - val_accuracy: 0.9031 - val_loss: 0.2307
# Epoch 43/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9392 - loss: 0.1589 - val_accuracy: 0.9038 - val_loss: 0.2286
# Epoch 44/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9370 - loss: 0.1616 - val_accuracy: 0.9034 - val_loss: 0.2292
# Epoch 45/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9411 - loss: 0.1570 - val_accuracy: 0.9049 - val_loss: 0.2284
# Epoch 46/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9395 - loss: 0.1562 - val_accuracy: 0.9048 - val_loss: 0.2270
# Epoch 47/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9409 - loss: 0.1513 - val_accuracy: 0.9056 - val_loss: 0.2264
# Epoch 48/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9426 - loss: 0.1472 - val_accuracy: 0.9054 - val_loss: 0.2258
# Epoch 49/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9431 - loss: 0.1475 - val_accuracy: 0.9065 - val_loss: 0.2259
# Epoch 50/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9442 - loss: 0.1475 - val_accuracy: 0.9065 - val_loss: 0.2255
# Epoch 51/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9453 - loss: 0.1444 - val_accuracy: 0.9065 - val_loss: 0.2248
# Epoch 52/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9489 - loss: 0.1394 - val_accuracy: 0.9068 - val_loss: 0.2254
# Epoch 53/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9493 - loss: 0.1370 - val_accuracy: 0.9030 - val_loss: 0.2308
# Epoch 54/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9442 - loss: 0.1440 - val_accuracy: 0.9064 - val_loss: 0.2274
# Epoch 55/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9484 - loss: 0.1368 - val_accuracy: 0.9082 - val_loss: 0.2216
# Epoch 56/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9488 - loss: 0.1351 - val_accuracy: 0.9071 - val_loss: 0.2250
# Epoch 57/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9481 - loss: 0.1363 - val_accuracy: 0.9077 - val_loss: 0.2272
# Epoch 58/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9507 - loss: 0.1302 - val_accuracy: 0.9095 - val_loss: 0.2234
# Epoch 59/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9558 - loss: 0.1257 - val_accuracy: 0.9065 - val_loss: 0.2263
# Epoch 60/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9538 - loss: 0.1271 - val_accuracy: 0.9092 - val_loss: 0.2285
#
# For 1.0e+05 samples:
# Best CNN test error rate: 9.0537% in epoch 58/60
#
#
# Training CNN model for 1.0e+06 samples
# Number of unique contributions: 13
# Total number of fractions: 28
# Total number of phases: 62
# Epoch 1/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 80ms/step - accuracy: 0.7760 - loss: 0.4843 - val_accuracy: 0.8385 - val_loss: 0.3426
# Epoch 2/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8499 - loss: 0.3222 - val_accuracy: 0.8781 - val_loss: 0.2732
# Epoch 3/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8840 - loss: 0.2629 - val_accuracy: 0.8999 - val_loss: 0.2305
# Epoch 4/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9073 - loss: 0.2204 - val_accuracy: 0.9177 - val_loss: 0.1982
# Epoch 5/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9206 - loss: 0.1929 - val_accuracy: 0.9265 - val_loss: 0.1797
# Epoch 6/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.9285 - loss: 0.1739 - val_accuracy: 0.9326 - val_loss: 0.1655
# Epoch 7/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - accuracy: 0.9351 - loss: 0.1609 - val_accuracy: 0.9353 - val_loss: 0.1580
# Epoch 8/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9385 - loss: 0.1509 - val_accuracy: 0.9391 - val_loss: 0.1498
# Epoch 9/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9415 - loss: 0.1462 - val_accuracy: 0.9412 - val_loss: 0.1468
# Epoch 10/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9454 - loss: 0.1380 - val_accuracy: 0.9398 - val_loss: 0.1487
# Epoch 11/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9455 - loss: 0.1357 - val_accuracy: 0.9423 - val_loss: 0.1421
# Epoch 12/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9478 - loss: 0.1317 - val_accuracy: 0.9454 - val_loss: 0.1362
# Epoch 13/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9490 - loss: 0.1289 - val_accuracy: 0.9457 - val_loss: 0.1353
# Epoch 14/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9504 - loss: 0.1261 - val_accuracy: 0.9466 - val_loss: 0.1325
# Epoch 15/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9505 - loss: 0.1251 - val_accuracy: 0.9476 - val_loss: 0.1304
# Epoch 16/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9527 - loss: 0.1210 - val_accuracy: 0.9481 - val_loss: 0.1300
# Epoch 17/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9520 - loss: 0.1208 - val_accuracy: 0.9473 - val_loss: 0.1308
# Epoch 18/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9530 - loss: 0.1202 - val_accuracy: 0.9492 - val_loss: 0.1272
# Epoch 19/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9546 - loss: 0.1162 - val_accuracy: 0.9480 - val_loss: 0.1295
# Epoch 20/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9551 - loss: 0.1156 - val_accuracy: 0.9500 - val_loss: 0.1262
# Epoch 21/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9554 - loss: 0.1139 - val_accuracy: 0.9500 - val_loss: 0.1261
# Epoch 22/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9560 - loss: 0.1130 - val_accuracy: 0.9495 - val_loss: 0.1267
# Epoch 23/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9575 - loss: 0.1090 - val_accuracy: 0.9508 - val_loss: 0.1244
# Epoch 24/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9560 - loss: 0.1118 - val_accuracy: 0.9513 - val_loss: 0.1227
# Epoch 25/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9572 - loss: 0.1096 - val_accuracy: 0.9514 - val_loss: 0.1235
# Epoch 26/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9573 - loss: 0.1104 - val_accuracy: 0.9479 - val_loss: 0.1293
# Epoch 27/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9578 - loss: 0.1079 - val_accuracy: 0.9517 - val_loss: 0.1221
# Epoch 28/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9598 - loss: 0.1057 - val_accuracy: 0.9516 - val_loss: 0.1224
# Epoch 29/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9586 - loss: 0.1064 - val_accuracy: 0.9518 - val_loss: 0.1226
# Epoch 30/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9594 - loss: 0.1049 - val_accuracy: 0.9516 - val_loss: 0.1225
# Epoch 31/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9600 - loss: 0.1035 - val_accuracy: 0.9513 - val_loss: 0.1234
# Epoch 32/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9597 - loss: 0.1036 - val_accuracy: 0.9525 - val_loss: 0.1206
# Epoch 33/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9600 - loss: 0.1039 - val_accuracy: 0.9532 - val_loss: 0.1196
# Epoch 34/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9595 - loss: 0.1032 - val_accuracy: 0.9528 - val_loss: 0.1201
# Epoch 35/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9606 - loss: 0.1019 - val_accuracy: 0.9521 - val_loss: 0.1212
# Epoch 36/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9615 - loss: 0.1007 - val_accuracy: 0.9531 - val_loss: 0.1191
# Epoch 37/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9610 - loss: 0.1000 - val_accuracy: 0.9526 - val_loss: 0.1207
# Epoch 38/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.9613 - loss: 0.0998 - val_accuracy: 0.9533 - val_loss: 0.1204
# Epoch 39/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9618 - loss: 0.0992 - val_accuracy: 0.9531 - val_loss: 0.1206
# Epoch 40/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9622 - loss: 0.0981 - val_accuracy: 0.9530 - val_loss: 0.1203
# Epoch 41/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9622 - loss: 0.0989 - val_accuracy: 0.9510 - val_loss: 0.1245
# Epoch 42/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9615 - loss: 0.0983 - val_accuracy: 0.9530 - val_loss: 0.1201
# Epoch 43/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9629 - loss: 0.0962 - val_accuracy: 0.9534 - val_loss: 0.1198
# Epoch 44/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9632 - loss: 0.0951 - val_accuracy: 0.9528 - val_loss: 0.1199
# Epoch 45/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9635 - loss: 0.0953 - val_accuracy: 0.9519 - val_loss: 0.1260
# Epoch 46/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9623 - loss: 0.0977 - val_accuracy: 0.9520 - val_loss: 0.1239
# Epoch 47/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9642 - loss: 0.0937 - val_accuracy: 0.9520 - val_loss: 0.1216
# Epoch 48/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9628 - loss: 0.0964 - val_accuracy: 0.9540 - val_loss: 0.1196
# Epoch 49/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9647 - loss: 0.0927 - val_accuracy: 0.9535 - val_loss: 0.1193
# Epoch 50/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9641 - loss: 0.0939 - val_accuracy: 0.9512 - val_loss: 0.1232
# Epoch 51/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9651 - loss: 0.0917 - val_accuracy: 0.9533 - val_loss: 0.1196
# Epoch 52/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9646 - loss: 0.0929 - val_accuracy: 0.9535 - val_loss: 0.1202
# Epoch 53/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9649 - loss: 0.0913 - val_accuracy: 0.9542 - val_loss: 0.1187
# Epoch 54/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9661 - loss: 0.0902 - val_accuracy: 0.9537 - val_loss: 0.1192
# Epoch 55/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9655 - loss: 0.0894 - val_accuracy: 0.9531 - val_loss: 0.1208
# Epoch 56/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9656 - loss: 0.0893 - val_accuracy: 0.9536 - val_loss: 0.1211
# Epoch 57/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9656 - loss: 0.0894 - val_accuracy: 0.9525 - val_loss: 0.1210
# Epoch 58/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9646 - loss: 0.0914 - val_accuracy: 0.9541 - val_loss: 0.1197
# Epoch 59/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9658 - loss: 0.0892 - val_accuracy: 0.9542 - val_loss: 0.1217
# Epoch 60/60
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9658 - loss: 0.0891 - val_accuracy: 0.9536 - val_loss: 0.1205
#
# For 1.0e+06 samples:
# Best CNN test error rate: 4.5815% in epoch 59/60
#
#
# Training CNN model for 1.0e+07 samples
# Number of unique contributions: 13
# Total number of fractions: 28
# Total number of phases: 62
# Epoch 1/60
# 1997/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8603 - loss: 0.3079
# 2024-06-19 23:33:07.931440: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1152000000 exceeds 10% of free system memory.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 132s 59ms/step - accuracy: 0.8604 - loss: 0.3077 - val_accuracy: 0.9449 - val_loss: 0.1378
# Epoch 2/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 110s 55ms/step - accuracy: 0.9481 - loss: 0.1313 - val_accuracy: 0.9518 - val_loss: 0.1226
# Epoch 3/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9535 - loss: 0.1181 - val_accuracy: 0.9560 - val_loss: 0.1128
# Epoch 4/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 110s 54ms/step - accuracy: 0.9565 - loss: 0.1117 - val_accuracy: 0.9571 - val_loss: 0.1112
# Epoch 5/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 110s 54ms/step - accuracy: 0.9581 - loss: 0.1077 - val_accuracy: 0.9590 - val_loss: 0.1055
# Epoch 6/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9593 - loss: 0.1046 - val_accuracy: 0.9590 - val_loss: 0.1056
# Epoch 7/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9601 - loss: 0.1028 - val_accuracy: 0.9601 - val_loss: 0.1028
# Epoch 8/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9610 - loss: 0.1010 - val_accuracy: 0.9610 - val_loss: 0.1006
# Epoch 9/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 110s 54ms/step - accuracy: 0.9619 - loss: 0.0991 - val_accuracy: 0.9609 - val_loss: 0.1010
# Epoch 10/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9620 - loss: 0.0985 - val_accuracy: 0.9614 - val_loss: 0.0998
# Epoch 11/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9628 - loss: 0.0967 - val_accuracy: 0.9618 - val_loss: 0.0991
# Epoch 12/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9627 - loss: 0.0966 - val_accuracy: 0.9623 - val_loss: 0.0977
# Epoch 13/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9634 - loss: 0.0952 - val_accuracy: 0.9623 - val_loss: 0.0979
# Epoch 14/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9636 - loss: 0.0946 - val_accuracy: 0.9622 - val_loss: 0.0989
# Epoch 15/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9640 - loss: 0.0941 - val_accuracy: 0.9629 - val_loss: 0.0964
# Epoch 16/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 110s 54ms/step - accuracy: 0.9641 - loss: 0.0937 - val_accuracy: 0.9629 - val_loss: 0.0965
# Epoch 17/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9645 - loss: 0.0927 - val_accuracy: 0.9633 - val_loss: 0.0955
# Epoch 18/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9646 - loss: 0.0926 - val_accuracy: 0.9624 - val_loss: 0.0974
# Epoch 19/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 110s 54ms/step - accuracy: 0.9646 - loss: 0.0920 - val_accuracy: 0.9634 - val_loss: 0.0951
# Epoch 20/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 55ms/step - accuracy: 0.9650 - loss: 0.0914 - val_accuracy: 0.9634 - val_loss: 0.0957
# Epoch 21/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9654 - loss: 0.0910 - val_accuracy: 0.9628 - val_loss: 0.0967
# Epoch 22/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9652 - loss: 0.0909 - val_accuracy: 0.9632 - val_loss: 0.0957
# Epoch 23/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9656 - loss: 0.0902 - val_accuracy: 0.9639 - val_loss: 0.0943
# Epoch 24/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9657 - loss: 0.0899 - val_accuracy: 0.9634 - val_loss: 0.0954
# Epoch 25/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9657 - loss: 0.0897 - val_accuracy: 0.9634 - val_loss: 0.0952
# Epoch 26/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9657 - loss: 0.0899 - val_accuracy: 0.9635 - val_loss: 0.0951
# Epoch 27/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9661 - loss: 0.0890 - val_accuracy: 0.9635 - val_loss: 0.0953
# Epoch 28/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9662 - loss: 0.0890 - val_accuracy: 0.9638 - val_loss: 0.0942
# Epoch 29/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9666 - loss: 0.0879 - val_accuracy: 0.9634 - val_loss: 0.0954
# Epoch 30/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9664 - loss: 0.0884 - val_accuracy: 0.9640 - val_loss: 0.0938
# Epoch 31/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9666 - loss: 0.0878 - val_accuracy: 0.9643 - val_loss: 0.0933
# Epoch 32/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9666 - loss: 0.0881 - val_accuracy: 0.9642 - val_loss: 0.0936
# Epoch 33/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9669 - loss: 0.0871 - val_accuracy: 0.9633 - val_loss: 0.0956
# Epoch 34/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9670 - loss: 0.0870 - val_accuracy: 0.9644 - val_loss: 0.0935
# Epoch 35/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9670 - loss: 0.0865 - val_accuracy: 0.9645 - val_loss: 0.0932
# Epoch 36/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9670 - loss: 0.0868 - val_accuracy: 0.9642 - val_loss: 0.0935
# Epoch 37/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9667 - loss: 0.0870 - val_accuracy: 0.9641 - val_loss: 0.0938
# Epoch 38/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9674 - loss: 0.0863 - val_accuracy: 0.9640 - val_loss: 0.0942
# Epoch 39/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9674 - loss: 0.0861 - val_accuracy: 0.9640 - val_loss: 0.0941
# Epoch 40/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9676 - loss: 0.0856 - val_accuracy: 0.9645 - val_loss: 0.0931
# Epoch 41/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9674 - loss: 0.0857 - val_accuracy: 0.9637 - val_loss: 0.0959
# Epoch 42/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9675 - loss: 0.0859 - val_accuracy: 0.9644 - val_loss: 0.0929
# Epoch 43/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9675 - loss: 0.0851 - val_accuracy: 0.9645 - val_loss: 0.0927
# Epoch 44/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9678 - loss: 0.0852 - val_accuracy: 0.9648 - val_loss: 0.0926
# Epoch 45/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9675 - loss: 0.0855 - val_accuracy: 0.9639 - val_loss: 0.0946
# Epoch 46/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9677 - loss: 0.0850 - val_accuracy: 0.9644 - val_loss: 0.0932
# Epoch 47/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9677 - loss: 0.0848 - val_accuracy: 0.9637 - val_loss: 0.0944
# Epoch 48/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9677 - loss: 0.0849 - val_accuracy: 0.9645 - val_loss: 0.0929
# Epoch 49/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9677 - loss: 0.0850 - val_accuracy: 0.9646 - val_loss: 0.0925
# Epoch 50/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9680 - loss: 0.0845 - val_accuracy: 0.9644 - val_loss: 0.0934
# Epoch 51/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9680 - loss: 0.0845 - val_accuracy: 0.9646 - val_loss: 0.0928
# Epoch 52/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9679 - loss: 0.0845 - val_accuracy: 0.9643 - val_loss: 0.0936
# Epoch 53/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 109s 54ms/step - accuracy: 0.9681 - loss: 0.0839 - val_accuracy: 0.9642 - val_loss: 0.0937
# Epoch 54/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9679 - loss: 0.0846 - val_accuracy: 0.9644 - val_loss: 0.0932
# Epoch 55/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9680 - loss: 0.0842 - val_accuracy: 0.9643 - val_loss: 0.0933
# Epoch 56/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.9682 - loss: 0.0840 - val_accuracy: 0.9637 - val_loss: 0.0950
# Epoch 57/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9683 - loss: 0.0838 - val_accuracy: 0.9640 - val_loss: 0.0940
# Epoch 58/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9683 - loss: 0.0836 - val_accuracy: 0.9645 - val_loss: 0.0935
# Epoch 59/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9683 - loss: 0.0832 - val_accuracy: 0.9644 - val_loss: 0.0938
# Epoch 60/60
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 108s 54ms/step - accuracy: 0.9683 - loss: 0.0835 - val_accuracy: 0.9647 - val_loss: 0.0926
#
# For 1.0e+07 samples:
# Best CNN test error rate: 3.5204% in epoch 44/60

# %%
# plot training history 
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(8, 10))
linewidth = 0.75
epochs = np.arange(1, n_epochs + 1)
plots = ["error rate", "loss"]
colors = []
for n_total, history, best in zip(n_totals, histories, best_rounds):
  for ax_i, plot in enumerate(plots):
    if plot == "error rate":
      train = 100*(1 - np.asarray(history.history['accuracy']))
      test = 100*(1 - np.asarray(history.history['val_accuracy']))
    else:
      train = history.history[plot]
      test = history.history[f"val_{plot}"]
    label = f'total samples = {n_total:0.1e}' if ax_i==0 else None
    line = axes[ax_i].plot(epochs, train, label=label,
                           linestyle='solid', linewidth=linewidth, marker='')
    colors.append(line[0].get_color())
    axes[ax_i].plot(epochs, test, linestyle='dashed', 
                    linewidth=linewidth, marker='', color=colors[-1])
    axes[ax_i].axhline(test[best], linestyle='dotted', alpha=0.6,
                       linewidth=linewidth, color=colors[-1])
    ylabel = "error rate [%]" if plot == "error rate" else plot
    axes[ax_i].set_ylabel(ylabel)
axes[-1].set_xlabel('Epoch')
axes[-1].plot([], [], linestyle='solid', linewidth=linewidth, 
        color='black', label='train')
axes[-1].plot([], [], linestyle='dashed', linewidth=linewidth, 
        color='black', label='test')
axes[-1].plot([], [], linestyle='dotted', linewidth=linewidth, 
        color='black', alpha=0.6, label='best of test')
axes[-1].legend()
axes[0].legend()

title = (f"CNN training: learning rate = {lr}\n"
         f"pymatching error: {100*pymatch_error_rate:0.3f}%")
for i, n_total in enumerate(n_totals):
    title += (f"\nwith {n_total:0.1e} samples, best test error: "
              f" {100*(1-best_accuracies[i]):.3f}%"
              f" in epoch {best_rounds[i] + 1}/{n_epochs}")
fig.suptitle(title)
filename = (f"CNNtraining-range.png")
fig.savefig(filename)

# %%
dt = time.time() - t0
print(F"full runtime: {dt/60:0.2f} mins")
# Out:
# full runtime: 138.89 mins
